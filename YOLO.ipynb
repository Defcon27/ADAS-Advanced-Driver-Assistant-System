# %% [markdown]
# # YOLO Object Detection

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2
from YOLO import ObjectDetection_yolo

# %%
# Out:
# [[573, 417, 64, 47], [639, 416, 78, 63]]
